# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator

# %%
# diagonalization
A = np.array([[2, 1],
              [1, 3]])

w, v = np.linalg.eigh(A)
print(w)
print(v)
# Out:
# [1.38196601 3.61803399]
# [[-0.85065081  0.52573111]
#  [ 0.52573111  0.85065081]]

# %% [markdown]
# ## numerical diagonalization of H_{BdG}
# 最小固有エネルギー $\delta E$ を計算する。

# %%
t = 1
N_list = [10]
Delta = 0.6

eps_abs_max = 12.0
steps = 1000

fig, ax = plt.subplots()
colors = plt.get_cmap("tab10").colors

for num, N in enumerate(N_list):
    eps_list = []
    dE_list = []
    weight_list = []
    for step in range(0, steps):

        eps = -eps_abs_max + 2*eps_abs_max*step/steps 
        eps_list.append(eps)
        i = np.arange(N-1)

        A = np.zeros((N, N)) 
        A[i, i] = - eps  
        A[i, i+1] = - t 
        A[i+1, i] = - t 

        B = np.zeros((N, N))
        B[i+1, i] = - Delta
        B[i, i+1] = Delta

        H = np.block([
        [A, B],
        [-B.conjugate().T, -A.conjugate().T]
        ])

        w, v = np.linalg.eigh(H)
        # print(w)
        # print(v[N])
        dE = w[N]
        dE_list.append(dE)
        weight_list.append([(np.abs(v[N][j])**2 + np.abs(v[N][j+N])**2) for j in range(N)])
    ax.scatter(eps_list, dE_list, s=2, label=f'$N={N}$', color=colors[num])

ax.axvline(x=+2, color='red', linestyle='--', linewidth=1)
ax.axvline(x=-2, color='red', linestyle='--', linewidth=1)

ax.set_xlabel(r"$\mu$")
ax.set_ylabel(r"$\delta E(\mu)$")
# ax.set_yscale("log")
ax.xaxis.set_major_locator(MultipleLocator(2))
ax.legend()

plt.show()

# %%
print(weight_list[0])
# Out:
# [np.float64(0.01792375041287475), np.float64(0.06538263200124782), np.float64(0.1254106245219525), np.float64(0.17620738008231449), np.float64(0.19891083802628123), np.float64(0.18435419968443761), np.float64(0.13689497524699473), np.float64(0.07402217948705528), np.float64(0.020859820495613586), np.float64(3.3600041227789666e-05)]

# %%
t = 1
N_list = [2,4,6,8,10,12,14,16]
Delta = 0.6

eps_abs_max = 2.0
steps = 1000

fig, ax = plt.subplots()
colors = plt.get_cmap("tab10").colors

for num, N in enumerate(N_list):
    eps_list = []
    dE_list = []
    weight_list = []
    for step in range(0, steps):

        eps = -eps_abs_max + 2*eps_abs_max*step/steps 
        eps_list.append(eps)
        i = np.arange(N-1)

        A = np.zeros((N, N)) 
        A[i, i] = - eps  
        A[i, i+1] = - t 
        A[i+1, i] = - t 

        B = np.zeros((N, N))
        B[i+1, i] = - Delta
        B[i, i+1] = Delta

        H = np.block([
        [A, B],
        [-B.conjugate().T, -A.conjugate().T]
        ])

        w, v = np.linalg.eigh(H)
        # print(w)
        # print(v)
        dE = w[N]
        dE_list.append(dE)
        # weight_list.append(v[N])
    ax.scatter(eps_list, dE_list, s=2, label=f'$N={N}$', color=colors[num])

ax.axvline(x=+2, color='red', linestyle='--', linewidth=1)
ax.axvline(x=-2, color='red', linestyle='--', linewidth=1)

ax.set_xlabel(r"$\mu$")
ax.set_ylabel(r"$\delta E(\mu)$")
ax.set_yscale("log")  # y軸を対数にする
ax.xaxis.set_major_locator(MultipleLocator(2))
ax.legend()

plt.show()

# %% [markdown]
# ## perturbation
# ある局所的なポテンシャル $\mathrm{H} = V c_1^\dagger c_1$ を加えた時の系の反応を見る。
#
# $\mu <=2.0$ の内側のほうが外側の場合よりも、$V (<<1)$ の変化に鋭敏に反応している。
# つまり、{{}}

# %%
t = 1
N_list = [3]
Delta = 0.6

eps_list = [-5,-4,-3,-2, 2,3,4,5]

V_steps = 1000
v_max = 5.0
v_min = -5.0

fig, ax = plt.subplots()
colors = plt.get_cmap("tab20").colors

for num, N in enumerate(N_list):
    weight_list = []
    for step, eps in enumerate(eps_list):
        # eps = eps_min + (eps_max-eps_min) / steps * step
        V_list = []
        dE_list = []
        # eps_list.append(eps)
        for V_step in range(0, V_steps):
            local_V = v_min + (v_max-v_min) / V_steps * V_step
            V_list.append(local_V)
            i = np.arange(N-1)

            A = np.zeros((N, N)) 
            A[i, i] = - eps  
            A[i, i+1] = - t 
            A[i+1, i] = - t 
            A[0, 0] += local_V

            B = np.zeros((N, N))
            B[i+1, i] = - Delta
            B[i, i+1] = Delta

            H = np.block([
            [A, B],
            [-B.conjugate().T, -A.conjugate().T]
            ])

            w, v = np.linalg.eigh(H)
            # print(w)
            # print(v[N])
            dE = w[N]
            dE_list.append(dE)
            # weight_list.append([(np.abs(v[N][j])**2 + np.abs(v[N][j+N])**2) for j in range(N)])
        ax.scatter(V_list, dE_list, s=2, label=f'$N={N}$, $\mu={eps}$', color=colors[step])

    # ax.axvline(x=+2, color='red', linestyle='--', linewidth=1)
    # ax.axvline(x=-2, color='red', linestyle='--', linewidth=1)

    ax.set_xlabel(r"$V$")
    ax.set_ylabel(r"$\delta E(\mu)$")
    ax.set_ylim(0, 0.2)
    # ax.set_yscale("log")
    ax.xaxis.set_major_locator(MultipleLocator(2))
    ax.legend(loc="upper left",
        bbox_to_anchor=(1.02, 1.0),
        borderaxespad=0)

    plt.show()
# Out:
# <>:47: SyntaxWarning: invalid escape sequence '\m'
# <>:47: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/v2/zf3jkdw95l3g90kly_0qx9lm0000gp/T/ipykernel_93834/3952893700.py:47: SyntaxWarning: invalid escape sequence '\m'
#   ax.scatter(V_list, dE_list, s=2, label=f'$N={N}$, $\mu={eps}$', color=colors[step])

# %%
t = 1
N_list = [3]
Delta = 0.6

# eps_list = [-5,-4,-3,-2, 2,3,4,5]
eps_list = [-1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5]

V_steps = 1000
v_max = 5.0
v_min = -5.0

fig, ax = plt.subplots()
colors = plt.get_cmap("tab20").colors

for num, N in enumerate(N_list):
    weight_list = []
    for step, eps in enumerate(eps_list):
        # eps = eps_min + (eps_max-eps_min) / steps * step
        V_list = []
        dE_list = []
        # eps_list.append(eps)
        for V_step in range(0, V_steps):
            local_V = v_min + (v_max-v_min) / V_steps * V_step
            V_list.append(local_V)
            i = np.arange(N-1)

            A = np.zeros((N, N)) 
            A[i, i] = - eps  
            A[i, i+1] = - t 
            A[i+1, i] = - t 
            A[0, 0] += local_V

            B = np.zeros((N, N))
            B[i+1, i] = - Delta
            B[i, i+1] = Delta

            H = np.block([
            [A, B],
            [-B.conjugate().T, -A.conjugate().T]
            ])

            w, v = np.linalg.eigh(H)
            # print(w)
            # print(v[N])
            dE = w[N]
            dE_list.append(dE)
            # weight_list.append([(np.abs(v[N][j])**2 + np.abs(v[N][j+N])**2) for j in range(N)])
        ax.scatter(V_list, dE_list, s=2, label=f'$N={N}$, $\mu={eps}$', color=colors[step])

    # ax.axvline(x=+2, color='red', linestyle='--', linewidth=1)
    # ax.axvline(x=-2, color='red', linestyle='--', linewidth=1)

    ax.set_xlabel(r"$V$")
    ax.set_ylabel(r"$\delta E(\mu)$")
    # ax.set_ylim(0, 0.2)
    # ax.set_yscale("log")
    ax.xaxis.set_major_locator(MultipleLocator(2))
    ax.legend(loc="upper left",
        bbox_to_anchor=(1.02, 1.0),
        borderaxespad=0)

    plt.show()
# Out:
# <>:48: SyntaxWarning: invalid escape sequence '\m'
# <>:48: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/v2/zf3jkdw95l3g90kly_0qx9lm0000gp/T/ipykernel_93834/3129193226.py:48: SyntaxWarning: invalid escape sequence '\m'
#   ax.scatter(V_list, dE_list, s=2, label=f'$N={N}$, $\mu={eps}$', color=colors[step])
