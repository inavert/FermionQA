# %% [markdown]
# ## Hubbard

# %%
vqe(
    model = 
    expectation_function = get_expectation_from_inner_product_between_statevector,
    optimizer=SPSA,
    backend = qsimcirq.QSimSimulator(qsimcirq.QSimOptions(max_fused_gate_size=2,cpu_threads=4)),
    qubits = cirq.LineQubit.range(8)
)
