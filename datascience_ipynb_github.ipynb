# %% [markdown]
# ## ipynbとGitHubの相性が悪い?
# - メタデータにシステム情報が入ってセキュリティ的に違和感
# - 複数人で実行するたびセルが別扱いになり、Gitに引っかかる
# - ...
#
# ## 対策
# - marimo
# - nbconvert
# - git commit hock
#
# - notebook は編集者を一人だけ割り当てて、他の人は触らない
# - 実行などしたら revert してもらう?
# - 気にせず毎回 commit?
# ~~- ipynb をやめる? ~~
